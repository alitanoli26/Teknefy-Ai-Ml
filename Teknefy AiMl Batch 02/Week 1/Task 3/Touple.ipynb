# %%
# A tuple is similar to a list but it cannot be changed (IMMUTABLE).
numbers = (10, 20, 30, 40)

# Accessing an element using index.
print(numbers[2])  # Prints the 3rd item (index starts from 0)
# Out:
# 30
