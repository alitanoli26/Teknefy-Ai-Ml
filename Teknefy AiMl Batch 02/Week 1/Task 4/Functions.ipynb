# %%
# We write the code once and use it many times.
def add(a, b):
    # The return keyword sends the result back to where the function was called.
    return a + b

print(add(5, 7))  # Calling the function with two numbers
