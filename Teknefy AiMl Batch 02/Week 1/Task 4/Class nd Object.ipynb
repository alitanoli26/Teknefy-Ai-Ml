# %%
# A CLASS is a blueprint.
# An OBJECT is something created from the class.

class Student:
    def __init__(self, name):
        self.name = name  # attribute of object

s1 = Student("Ali")  # creating an object
print(s1.name)
# Out:
# Ali
