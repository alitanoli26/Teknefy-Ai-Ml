# %%
# Parent class
class Animal:
    def speak(self):
        print("Animal makes sound")

# Child class inherits the parent class.
# Dog automatically gets all methods of Animal.
class Dog(Animal):
    def bark(self):
        print("Dog barks")

# Creating object
d = Dog()
d.speak()  # inherited method
d.bark()   # Dog's own method
