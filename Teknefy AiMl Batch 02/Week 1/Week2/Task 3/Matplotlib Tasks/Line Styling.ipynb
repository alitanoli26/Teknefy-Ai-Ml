# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("university_data.csv")
plt.plot(df["Marks"], color="green", marker="o", linestyle="--")
plt.title("Styled Line Plot")
plt.show()
