# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("university_data.csv")
plt.figure(figsize=(8,4))
plt.plot(df["Marks"])
plt.title("Bigger Figure")
plt.show()
