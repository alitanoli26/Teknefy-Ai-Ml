# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("university_data.csv")
plt.scatter(df["Department"], df["Marks"])
plt.title("Department vs Marks")
plt.xlabel("Department")
plt.ylabel("Marks")
plt.show()
