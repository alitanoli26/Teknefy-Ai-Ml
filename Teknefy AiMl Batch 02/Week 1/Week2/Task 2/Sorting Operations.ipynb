# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
# Sort RollNumber in descending order
sorted_df = df.sort_values(by="Roll Number", ascending=False)
print(sorted_df.head())
# Out:
#            Name Roll Number   Department  Age  Marks
# 9    Hina Saeed    AUST-110      English   22     87
# 8   Usman Javed    AUST-109    Economics   23     89
# 7   Laiba Tariq    AUST-108  Mathematics   19     89
# 11  Laiba Tariq    AUST-108  Mathematics   18     89
# 6     Hamza Ali    AUST-107      Physics   21     87
