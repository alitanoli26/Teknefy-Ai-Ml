# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
grouped = df.groupby("Department")["Marks"].mean() # we have calculated the mean of the marks by grouping the students of same departments
print(grouped)
# Out:
# Department
# AI             57.0
# CS             68.0
# Chemistry      68.0
# Economics      89.0
# English        87.0
# IT             87.0
# Mathematics    89.0
# Physics        87.0
# Zoology        88.0
# Name: Marks, dtype: float64
