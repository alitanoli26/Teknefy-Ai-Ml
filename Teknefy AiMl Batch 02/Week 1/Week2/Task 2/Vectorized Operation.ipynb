# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
df["Updated_Marks"] = df["Marks"] + 3 # every student will get 3 extra  marks
print(df.head())
# Out:
#             Name Roll Number Department  Age  Marks  Updated_Marks
# 0       Ali Khan    AUST-101         CS   23     68             71
# 1     Sara Ahmed    AUST-102         IT   23     98            101
# 2     Sara Ahmed    AUST-102         IT   19     76             79
# 3    Ayesha Noor    AUST-104         AI   21     57             60
# 4  Bilal Hussain    AUST-105    Zoology   22     88             91
