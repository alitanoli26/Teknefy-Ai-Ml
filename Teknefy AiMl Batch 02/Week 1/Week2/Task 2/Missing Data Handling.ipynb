# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
# Create a missing value
df.loc[0, "Score"] = None

# Check missing values
print(df.isnull().sum())

# Fill missing value
df["Score"] = df["Score"].fillna(df["Score"].mean())
# Out:
# Name            0
# Roll Number     0
# Department      0
# Age             0
# Marks           0
# Score          12
# dtype: int64
# C:\Users\dell\AppData\Local\Temp\ipykernel_12376\3916316783.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Score"] = df["Score"].fillna(df["Score"].mean())
