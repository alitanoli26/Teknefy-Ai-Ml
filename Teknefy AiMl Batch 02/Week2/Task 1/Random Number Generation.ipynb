# %%
import numpy as np
r=np.random.randint(1,10,5) #Random Integers numbers in between 1-10
print(r)
# Out:
# [9 1 5 7 7]

# %%
g=np.random.rand(5) #Random floating point Numbers or Decimal Numbers
print(g)
# Out:
# [0.2816158  0.16829067 0.25315084 0.13728878 0.9915443 ]
