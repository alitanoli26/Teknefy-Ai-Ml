# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
# Rename columns
df.rename(columns={"Name": "Student Name"}, inplace=True)
print(df.head())
# Out:
#     Student Name Roll Number Department  Age  Marks
# 0       Ali Khan    AUST-101         CS   23     68
# 1     Sara Ahmed    AUST-102         IT   23     98
# 2     Sara Ahmed    AUST-102         IT   19     76
# 3    Ayesha Noor    AUST-104         AI   21     57
# 4  Bilal Hussain    AUST-105    Zoology   22     88

# %%
# Remove duplicates
df = df.drop_duplicates()
print(df.head())
# Out:
#     Student Name Roll Number Department  Age  Marks
# 0       Ali Khan    AUST-101         CS   23     68
# 1     Sara Ahmed    AUST-102         IT   23     98
# 2     Sara Ahmed    AUST-102         IT   19     76
# 3    Ayesha Noor    AUST-104         AI   21     57
# 4  Bilal Hussain    AUST-105    Zoology   22     88
