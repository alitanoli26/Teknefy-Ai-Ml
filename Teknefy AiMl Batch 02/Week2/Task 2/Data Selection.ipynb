# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv("data.csv")
# Single column
print(df["Name"])
print("\n")
# Multiple columns
print(df[["Name", "Department"]])
# Out:
# 0           Ali Khan
# 1         Sara Ahmed
# 2         Sara Ahmed
# 3        Ayesha Noor
# 4      Bilal Hussain
# 5     Mehwish Fatima
# 6          Hamza Ali
# 7        Laiba Tariq
# 8        Usman Javed
# 9         Hina Saeed
# 10     Bilal Hussain
# 11       Laiba Tariq
# Name: Name, dtype: object
#
#
#               Name   Department
# 0         Ali Khan           CS
# 1       Sara Ahmed           IT
# 2       Sara Ahmed           IT
# 3      Ayesha Noor           AI
# 4    Bilal Hussain      Zoology
# 5   Mehwish Fatima    Chemistry
# 6        Hamza Ali      Physics
# 7      Laiba Tariq  Mathematics
# 8      Usman Javed    Economics
# 9       Hina Saeed      English
# 10   Bilal Hussain      Zoology
# 11     Laiba Tariq  Mathematics
