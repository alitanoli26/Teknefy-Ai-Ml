# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("university_data.csv")
sns.countplot(x="Department", data=df)
plt.title("Count of Students by Department")
plt.show()
