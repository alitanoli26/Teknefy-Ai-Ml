# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("university_data.csv")
plt.bar(df["Student"][:10], df["Marks"][:10])
plt.xticks(rotation=90)
plt.title("Marks of First 10 Students")
plt.ylabel("Marks")
plt.show()
