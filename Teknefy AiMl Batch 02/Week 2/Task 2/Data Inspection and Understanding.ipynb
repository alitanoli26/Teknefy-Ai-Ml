# %%
# Load the CSV file
df = pd.read_csv("data.csv")
#this is used to understand the data sets
print(df.head()) #head() — first rows

print(df.tail())   #tail() — last rows

print(df.info())  #info() — columns + data types

print(df.describe())  #describe() — statistics
# Out:
#             Name Roll Number Department  Age  Marks
# 0       Ali Khan    AUST-101         CS   23     68
# 1     Sara Ahmed    AUST-102         IT   23     98
# 2     Sara Ahmed    AUST-102         IT   19     76
# 3    Ayesha Noor    AUST-104         AI   21     57
# 4  Bilal Hussain    AUST-105    Zoology   22     88
#              Name Roll Number   Department  Age  Marks
# 7     Laiba Tariq    AUST-108  Mathematics   19     89
# 8     Usman Javed    AUST-109    Economics   23     89
# 9      Hina Saeed    AUST-110      English   22     87
# 10  Bilal Hussain    AUST-105      Zoology   21     88
# 11    Laiba Tariq    AUST-108  Mathematics   18     89
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         12 non-null     object
#  1   Roll Number  12 non-null     object
#  2   Department   12 non-null     object
# ...
